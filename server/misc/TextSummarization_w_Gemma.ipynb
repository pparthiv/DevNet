# %%
# %pip install bitsandbytes==0.42.0
# %pip install peft==0.8.2
# %pip install trl==0.7.10
# %pip install accelerate==0.27.1
# %pip install datasets==2.17.0
# %pip install transformers==4.38.0
# %pip install langchain
# %pip install wheel
# %pip install flash-attn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# ...
#   Using cached flash_attn-2.5.8.tar.gz (2.5 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [22 lines of output]
#       fatal: not a git repository (or any of the parent directories): .git
#
#
#       torch.__version__  = 2.3.0+cpu
#
#
# ...

# %%
# %pip install langchain-community
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 445.2 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/2.1 MB 655.4 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/2.1 MB 778.5 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/2.1 MB 986.4 kB/s eta 0:00:02
#    ------- -------------------------------- 0.4/2.1 MB 1.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/2.1 MB 1.7 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 2.2 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.1 MB 2.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.1 MB 3.2 MB/s eta 0:00:01
# ...

# %%
from playwright.sync_api import sync_playwright
from playwright.async_api import async_playwright, Playwright
from bs4 import BeautifulSoup
import time
import json
from dotenv import load_dotenv
import os
import asyncio
from langchain_core.prompts.prompt import PromptTemplate
from langchain_community.llms.huggingface_endpoint import HuggingFaceEndpoint
from langchain.chains.llm import LLMChain
import random
import requests

# %%
load_dotenv()
# Out:
# True

# %%
template = "Write a short, concise and objective description of a student programmer based on their LinkedIn profile. This individual has experience in building applications and is proficient in {skills}. Focus on the top 10 most valuable skills that are directly related to programming. They hold the following certifications: {certs}. Highlight their strongest fields in your judgement from the skills given and the skills in a neutral and honest manner to provide a clear and accurate representation."
prompt = PromptTemplate(
    template=template,
    input_variables=['about', 'skills', 'certs']
)

# %%
template = """Extract and list only the programming skills mentioned in the following LinkedIn {category}. Provide only a concise array without any additional information or description.
    LinkedIn {category}: {value}
    Programming Skills:
"""
prompt = PromptTemplate(
    template=template,
    input_variables=['category', 'value']
)

# %%
gemma_7b = HuggingFaceEndpoint(repo_id='mistralai/Mistral-7B-Instruct-v0.2', temperature=0.1, huggingfacehub_api_token="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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to C:\Users\parth\.cache\huggingface\token
# Login successful

# %%
candidate = open("../../Misc/text.json")

# %%
candidate_data = json.load(candidate)

# %%
about = candidate_data["Summary"]
skills = candidate_data["Skills"]
certs = candidate_data["Certifications"]

# %%
template = """Extract and list only the programming and technical skills mentioned in the following project descriptions. Provide only the skills without any additional information.

Project Descriptions:
{projects}

Skills: [only skills separated by ;]"""

prompt = PromptTemplate(
    template=template,
    input_variables=['projects']
)

# %%
val_str = " | ".join(["Hestia is an innovative app designed for community use, allowing NGOs and government bodies to monitor homeless individuals via a database that timestamps and geotags their locations. This aids in optimizing donation efforts and offering tailored assistance in line with UN Sustainable Development Goals 1, 10, 11, and 16, which focus on tackling poverty, reducing inequalities, promoting sustainable urban development, and fostering peace and justice.The technology behind Hestia comprises Flutter for the mobile app, React for the Admin and NGO Portal, machine learning for mapping regions and identifying faces, and deployment via Docker and Cloud Build on Google Cloud Platform. The app stands out with its method of marking individuals through photos, creating map markers for region mapping, thus facilitating efficient tracking for donation and support initiatives.A key aspect of Hestia is its SOS reporting system, enabling users to report criminal activities nearby. Administrators receive alerts through portals, utilizing face clustering to identify recurring markers and aiding in locating individuals, particularly useful in cases such as Alzheimer's patients or natural disasters.Moreover, Hestia incorporates a community feature where users can share general or donation-related content. NGOs manage the collection and distribution of donated items, encouraging community involvement. Monetary donations are also seamlessly facilitated through the platform. Additionally, the app includes a chatbot for addressing homelessness-related inquiries and a Settings screen for user personalization.The administrative portal provides administrators with a comprehensive overview of SOS reports and clustered markers. Admins can manually trigger the creation of region maps from new markers, ensuring timely updates and optimal utilization of the app's features.",
 'A dynamic R shinyapp and an RMarkdown project aiming to visualize the statistical performance of Premier League Forwards 2022/23.'])

# %%
llm_chain = LLMChain(
    prompt=prompt,
    llm=gemma_7b
)
# ask the question about Kaggle
res = llm_chain.run({"projects": val_str})

# %%
res
# Out:
# '\nFlutter; React; machine learning; Docker; Cloud Build; Google Cloud Platform; face clustering; SOS reporting system; R; RShiny; RMarkdown; statistical performance analysis.'

# %%
gen_skills = []
for item in res.split(";"):
    temp = item.replace('\n', " ").lstrip().rstrip().rstrip('.')
    final_word = []
    for word in temp.split(" "):
        final_word.append(word.capitalize())
    if len(final_word) > 0:
        gen_skills.append(" ".join(final_word))

# %%
gen_skills
# Out:
# ['Flutter',
#  'React',
#  'Machine Learning',
#  'Docker',
#  'Cloud Build',
#  'Google Cloud Platform',
#  'Face Clustering',
#  'Sos Reporting System',
#  'R',
#  'Rshiny',
#  'Rmarkdown',
#  'Statistical Performance Analysis']

# %%
print("\n\nExample:\n\nStudent Programmer\n\nThis individual is a proficient programmer with experience in building applications using [Java, Python, C++]. Their skillset includes:\n\n1. Strong foundation in programming concepts such as data structures, algorithms, and object-oriented design.\n2. Proficient in [Java, Python, C++] with a solid understanding of syntax, libraries, and frameworks.\n3. Familiarity with front-end technologies such as HTML, CSS, and JavaScript for building user interfaces.\n4. Experience with databases and SQL for data storage and retrieval.\n5. Knowledge of version control systems like Git for managing code repositories.\n6. Familiarity with Agile methodologies and Scrum framework for software development.\n7. Strong problem-solving abilities and attention to detail.\n8. Excellent communication skills and ability to work in a team.\n9. Continuously expanding their knowledge through self-study and attending industry events.\n10. Certified in [Oracle Certified Professional, Java SE 8 Programmer, Microsoft Technology Associate].\n\nTheir strongest fields appear to be in Java and object-oriented design, as evidenced by their experience and certifications. However, they also have a solid foundation in other programming languages and technologies.")
# Out:
# Example:
#
# Student Programmer
#
# This individual is a proficient programmer with experience in building applications using [Java, Python, C++]. Their skillset includes:
#
# 1. Strong foundation in programming concepts such as data structures, algorithms, and object-oriented design.
# 2. Proficient in [Java, Python, C++] with a solid understanding of syntax, libraries, and frameworks.
# 3. Familiarity with front-end technologies such as HTML, CSS, and JavaScript for building user interfaces.
# 4. Experience with databases and SQL for data storage and retrieval.
# 5. Knowledge of version control systems like Git for managing code repositories.
# 6. Familiarity with Agile methodologies and Scrum framework for software development.
# 7. Strong problem-solving abilities and attention to detail.
# 8. Excellent communication skills and ability to work in a team.
# 9. Continuously expanding their knowledge through self-study and attending industry events.
# ...

# %%
HTMLFile = open("html.html", "r")

# %%
index = HTMLFile.read()

# %%
soup = BeautifulSoup(index, 'html.parser')

# %%
exp_list = soup.find(lambda tag: tag.name=='section' and tag.has_attr('data-section') and tag['data-section']=="experience").find("ul").find_all("li")

# %%
experiences = []
for i in range(len(exp_list)):
    title = exp_list[i].find("div").find("span", class_="experience-item__title")
    if not title:
        continue
    title = title.text.replace('\n', " ").lstrip().rstrip()

    subtitle = exp_list[i].find("div").find("span", class_="experience-item__subtitle")
    if not title:
        continue
    subtitle = subtitle.text.replace('\n', " ").lstrip().rstrip()

    experiences.append(f"{title} at {subtitle}")

# %%
experiences
# Out:
# ['SDE Intern at SpArts Technologies',
#  'Vice President at AEC Coding Club',
#  'Member at AEC Coding Club',
#  'GDSC Lead at Google Developer Student Club (AEC)',
#  'Technical Coordinator at Google Developer Student Club (AEC)',
#  'Summer Intern at Indian Institute of Technology, Guwahati']

# %%
certs_list = soup.find(lambda tag: tag.name=='section' and tag.has_attr('data-section') and tag['data-section']=="certifications").find("ul").find_all("li")

# %%
certs_list[0]
# Out:
# <li class="profile-section-card relative flex w-full list-none py-1.5 pr-2 pl-1">
# <!-- --> <a class="profile-section-card__image-link" data-tracking-control-name="public_profile_profile-section-card_image-click" data-tracking-will-navigate="" href="https://www.linkedin.com/company/codecademy?trk=public_profile_profile-section-card_image-click">
# <img alt="Apply Natural Language Processing with Python Skill Path Graphic" class="inline-block relative w-6 h-6 shrink-0 mr-0.5 border-4 border-color-transparent border-solid box-content rounded-[6px] profile-section-card__image" data-delayed-url="https://media.licdn.com/dms/image/D4E0BAQHQ2d_UpqzPHg/company-logo_100_100/0/1688566825101/codecademy_logo?e=2147483647&amp;v=beta&amp;t=tgzkn6sh68GOSjKjoH3oiOA9fbkmERS9XTppDGJ2dks" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/cs8pjfgyw96g44ln9r7tct85f"/>
# </a>
# <div class="pl-0.5 grow break-words">
# ...

# %%
certs = []
for i in range(len(certs_list)):
    cert_title = certs_list[i].find("div").find("h3").find("a").text.replace('\n', " ").lstrip().rstrip()
    certs.append(cert_title)

# %%
certs
# Out:
# ['Apply Natural Language Processing with Python Skill Path',
#  'Create a Back-End App with JavaScript Skill Path',
#  'Create a Front-End App with React Skill Path',
#  'Build Python Web Apps with Django Skill Path',
#  'DeepLearning.AI TensorFlow Developer Specialization',
#  'Google Data Analytics Specialization']

# %%
proj_list = soup.find(lambda tag: tag.name=='section' and tag.has_attr('data-section') and tag['data-section']=="projects").find("ul").find_all("li")

# %%
projects = []
for i in range(len(proj_list)):
    if proj_list[i].find("div") is None:
        continue
    desc = proj_list[i].find("div").find("div").find("div").find("p", class_="show-more-less-text__text--less").text.replace('\n', " ").lstrip().rstrip()
    if proj_list[i].find("div").find("div").find("div").find("p", class_="show-more-less-text__text--more"):
        desc = proj_list[i].find("div").find("div").find("div").find("p", class_="show-more-less-text__text--more").text.replace('Show less', " ").replace('\n', " ").lstrip().rstrip()
    projects.append(desc)

# %%
projects
# Out:
# ["Hestia is an innovative app designed for community use, allowing NGOs and government bodies to monitor homeless individuals via a database that timestamps and geotags their locations. This aids in optimizing donation efforts and offering tailored assistance in line with UN Sustainable Development Goals 1, 10, 11, and 16, which focus on tackling poverty, reducing inequalities, promoting sustainable urban development, and fostering peace and justice.The technology behind Hestia comprises Flutter for the mobile app, React for the Admin and NGO Portal, machine learning for mapping regions and identifying faces, and deployment via Docker and Cloud Build on Google Cloud Platform. The app stands out with its method of marking individuals through photos, creating map markers for region mapping, thus facilitating efficient tracking for donation and support initiatives.A key aspect of Hestia is its SOS reporting system, enabling users to report criminal activities nearby. Administrators rece
# ...
